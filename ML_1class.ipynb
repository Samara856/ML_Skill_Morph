# %% [markdown]
# <a href="https://colab.research.google.com/github/Samara856/ML_Skill_Morph/blob/main/ML_1class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("This is my first program for Skill Morph")
# Out:
# This is my first program for Skill Morph
